# %%
import numpy as np
import os
import json
import sys
import matplotlib.pyplot as plt
import skimage

sys.path.append("../")
import src.plot as myplot
import seaborn as sns

import sklearn

# %%
import importlib
import src.plot as myplot
importlib.reload(myplot)
# Out:
# <module 'src.plot' from '/Users/paulhosek/PycharmProjects/mcm/MCM_classifier/Classifier_1/mcm/paper_plots/../src/plot.py'>

# %%
import importlib
import src.paper_utils as utils
importlib.reload(utils)
# Out:
# <module 'src.paper_utils' from '/Users/paulhosek/PycharmProjects/mcm/MCM_classifier/Classifier_1/mcm/paper_plots/../src/paper_utils.py'>

# %%
sample_sizes_all = [10] + list(np.arange(100,5400,100)) + [5423]

# %%
# # call multiple times to not run out of memory

# out = list()
# for i, ss in enumerate(sample_sizes_all):
#     print(ss)

#     counts_samplesizes, mcms_samplesizes = utils.load_counts_mcm([ss], letter="", path_format="../data/Output/mcm/sample_sizes")
#     atest_mcms, atest_probs = utils.get_complete_testprobs(mcms_samplesizes,counts_samplesizes,[ss],n_runs=10,smooth=True)
#     out.append(utils.mean_testacc_runmean(atest_probs))
    
#     print(ss)

# %%
# result = np.array(out)
# file_path = "./test_accuracies_over_sample_sizes.txt"
# np.savetxt(file_path, result, delimiter=',')

# %%
out = np.loadtxt("./test_accuracies_over_sample_sizes_true.txt", delimiter=',')
result = np.array(out)
result.shape
np.mean(result, axis=1)
np.min(result, axis=1)
np.max(result,axis=1)
# Out:
# array([0.71591928, 0.86995516, 0.89103139, 0.89966368, 0.90616592,
#        0.90829596, 0.9088565 , 0.91367713, 0.91334081, 0.91502242,
#        0.9206278 , 0.91782511, 0.91939462, 0.92331839, 0.92107623,
#        0.92253363, 0.92488789, 0.9205157 , 0.92466368, 0.92443946,
#        0.92399103, 0.92556054, 0.92331839, 0.92488789, 0.92769058,
#        0.92825112, 0.92477578, 0.92668161, 0.92690583, 0.9264574 ,
#        0.925     , 0.92578475, 0.92724215, 0.92825112, 0.92847534,
#        0.92612108, 0.92813901, 0.92914798, 0.92881166, 0.92802691,
#        0.92825112, 0.92858744, 0.93060538, 0.92836323, 0.9279148 ,
#        0.92970852, 0.92982063, 0.92836323, 0.92892377, 0.92892377,
#        0.92982063, 0.92847534, 0.93015695, 0.92769058, 0.93060538])

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.plot(sample_sizes_all, np.mean(result, axis=1), color='blue', label='Mean')
plt.fill_between(sample_sizes_all, np.min(result, axis=1), np.max(result, axis=1), color='lightblue', alpha=0.3, label='Error Band')

# Set the x-axis labels
plt.xticks(list(range(0,5400,200))+[5423], rotation=90)

# Set the axis labels and title
plt.xlabel('Training sample size')
plt.ylabel('Test accuracy')
# plt.xticks([0]+sample_sizes_all[1::2] + [5423], rotation=90)

# Show the plot
plt.savefig("./img/test_accuracies_overN.png", dpi=300, bbox_inches="tight")

# %%
raise KeyboardInterrupt # for now

# %%
import os

# Get the current directory
current_dir = os.getcwd()

# Create the file path
file_path = os.path.join(current_dir, "test_accuracies_over_sample_sizes.txt")

# Open the file in write mode
with open(file_path, "w") as file:
    # Write the list "out" to the file
    for item in out:
        file.write(str(item) + "\n")

# %%
import numpy as np

file_path = '/Users/paulhosek/PycharmProjects/mcm/MCM_classifier/Classifier_1/mcm/paper_plots/test_accuracies_over_sample_sizes.txt'
data = np.loadtxt(file_path)

print(data)
# Out:
# []
# /var/folders/z9/j9843dsj2t5dsl2bv81xcwww0000gn/T/ipykernel_66915/2957816864.py:4: UserWarning: loadtxt: input contained no data: "/Users/paulhosek/PycharmProjects/mcm/MCM_classifier/Classifier_1/mcm/paper_plots/test_accuracies_over_sample_sizes.txt"
#   data = np.loadtxt(file_path)

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.plot(sample_sizes_all, data, marker='o')

# Set the x-axis labels
plt.xticks(sample_sizes_all, rotation=90)

# Set the axis labels and title
plt.xlabel('Training sample size')
plt.ylabel('Test accuracy')
plt.xticks([0]+sample_sizes_all[1::2] + [5423], rotation=90)

# Show the plot
plt.savefig("./img/test_accuracies_overN.png", dpi=300, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[17], line 4
#
#       1 import matplotlib.pyplot as plt
#
#       3 # Create the plot
#
# ----> 4 plt.plot(sample_sizes_all, data, marker='o')
#
#       6 # Set the x-axis labels
#
#       7 plt.xticks(sample_sizes_all, rotation=90)
#
#
#
# File ~/opt/anaconda3/envs/mcm_classifying/lib/python3.11/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#
#    3571 def plot(
#
#    3572     *args: float | ArrayLike | str,
#
#    (...)
#
#    3576     **kwargs,
#
#    3577 ) -> list[Line2D]:
#
# -> 3578     return gca().plot(
#
#    3579         *args,
#
#    3580         scalex=scalex,
#
#    3581         scaley=scaley,
#
#    3582         **({"data": data} if data is not None else {}),
#
#    3583         **kwargs,
#
#    3584     )
#
#
#
# File ~/opt/anaconda3/envs/mcm_classifying/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#
#    1478 """
#
#    1479 Plot y versus x as lines and/or markers.
#
#    1480
#
#    (...)
#
#    1718 (``'green'``) or hex strings (``'#008000'``).
#
#    1719 """
#
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
#
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#
#    1722 for line in lines:
#
#    1723     self.add_line(line)
#
#
#
# File ~/opt/anaconda3/envs/mcm_classifying/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#
#     301     this += args[0],
#
#     302     args = args[1:]
#
# --> 303 yield from self._plot_args(
#
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
#
#
# File ~/opt/anaconda3/envs/mcm_classifying/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#
#     496     axes.yaxis.update_units(y)
#
#     498 if x.shape[0] != y.shape[0]:
#
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#
#     500                      f"have shapes {x.shape} and {y.shape}")
#
#     501 if x.ndim > 2 or y.ndim > 2:
#
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#
#     503                      f"shapes {x.shape} and {y.shape}")
#
#
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (0,)

# %%
sample_sizes_all.index(2000)
# Out:
# 19

# %%
data[20]
# Out:
# 0.9162556053811658
